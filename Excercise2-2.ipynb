# %%
# Load libraries
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.layers import Conv2D, MaxPooling2D
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load the Fashion MNIST dataset
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
# Data normalize and reshape
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255

train_images = train_images.reshape(60000, 28, 28, 1)
test_images = test_images.reshape(10000, 28, 28, 1)

# %%
# Model built
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten()) 
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
# Compile model
opt_rms = keras.optimizers.RMSprop(learning_rate=0.001, decay=1e-4)
model.compile(loss='sparse_categorical_crossentropy', optimizer=opt_rms, metrics=['accuracy'])

# %%
# Train data
model.fit(train_images, train_labels, epochs=25, batch_size=128, validation_data = (test_images, test_labels))
# Out:
# Epoch 1/25
# 469/469 [==============================] - 15s 13ms/step - loss: 0.9536 - accuracy: 0.6524 - val_loss: 0.5911 - val_accuracy: 0.7809
# Epoch 2/25
# 469/469 [==============================] - 5s 11ms/step - loss: 0.6112 - accuracy: 0.7797 - val_loss: 0.5038 - val_accuracy: 0.8169
# Epoch 3/25
# 469/469 [==============================] - 5s 12ms/step - loss: 0.5324 - accuracy: 0.8115 - val_loss: 0.4713 - val_accuracy: 0.8292
# Epoch 4/25
# 469/469 [==============================] - 5s 12ms/step - loss: 0.4843 - accuracy: 0.8287 - val_loss: 0.4329 - val_accuracy: 0.8385
# Epoch 5/25
# 469/469 [==============================] - 5s 11ms/step - loss: 0.4491 - accuracy: 0.8431 - val_loss: 0.4047 - val_accuracy: 0.8542
# Epoch 6/25
# 469/469 [==============================] - 6s 12ms/step - loss: 0.4226 - accuracy: 0.8509 - val_loss: 0.3872 - val_accuracy: 0.8583
# Epoch 7/25
# 469/469 [==============================] - 5s 11ms/step - loss: 0.4028 - accuracy: 0.8574 - val_loss: 0.3879 - val_accuracy: 0.8546
# Epoch 8/25
# 469/469 [==============================] - 5s 11ms/step - loss: 0.3833 - accuracy: 0.8649 - val_loss: 0.3808 - val_accuracy: 0.8566
# Epoch 9/25
# 469/469 [==============================] - 5s 12ms/step - loss: 0.3660 - accuracy: 0.8714 - val_loss: 0.3769 - val_accuracy: 0.8628
# Epoch 10/25
# 469/469 [==============================] - 5s 11ms/step - loss: 0.3563 - accuracy: 0.8749 - val_loss: 0.3590 - val_accuracy: 0.8688
# Epoch 11/25
# 469/469 [==============================] - 5s 12ms/step - loss: 0.3453 - accuracy: 0.8778 - val_loss: 0.3418 - val_accuracy: 0.8762
# Epoch 12/25
# 469/469 [==============================] - 5s 11ms/step - loss: 0.3360 - accuracy: 0.8813 - val_loss: 0.3466 - val_accuracy: 0.8783
# Epoch 13/25
# 469/469 [==============================] - 5s 12ms/step - loss: 0.3242 - accuracy: 0.8842 - val_loss: 0.3634 - val_accuracy: 0.8646
# Epoch 14/25
# 469/469 [==============================] - 5s 11ms/step - loss: 0.3164 - accuracy: 0.8881 - val_loss: 0.3431 - val_accuracy: 0.8811
# Epoch 15/25
# 469/469 [==============================] - 5s 12ms/step - loss: 0.3074 - accuracy: 0.8908 - val_loss: 0.3295 - val_accuracy: 0.8817
# Epoch 16/25
# 469/469 [==============================] - 5s 11ms/step - loss: 0.3033 - accuracy: 0.8924 - val_loss: 0.3326 - val_accuracy: 0.8798
# Epoch 17/25
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2978 - accuracy: 0.8948 - val_loss: 0.3268 - val_accuracy: 0.8817
# Epoch 18/25
# 469/469 [==============================] - 5s 12ms/step - loss: 0.2914 - accuracy: 0.8973 - val_loss: 0.3377 - val_accuracy: 0.8823
# Epoch 19/25
# 469/469 [==============================] - 5s 12ms/step - loss: 0.2866 - accuracy: 0.8987 - val_loss: 0.3264 - val_accuracy: 0.8824
# Epoch 20/25
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2826 - accuracy: 0.8988 - val_loss: 0.3256 - val_accuracy: 0.8857
# Epoch 21/25
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2762 - accuracy: 0.9025 - val_loss: 0.3396 - val_accuracy: 0.8841
# Epoch 22/25
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2730 - accuracy: 0.9039 - val_loss: 0.3273 - val_accuracy: 0.8880
# Epoch 23/25
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2671 - accuracy: 0.9050 - val_loss: 0.3142 - val_accuracy: 0.8877
# Epoch 24/25
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2640 - accuracy: 0.9065 - val_loss: 0.3211 - val_accuracy: 0.8895
# Epoch 25/25
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2590 - accuracy: 0.9074 - val_loss: 0.3294 - val_accuracy: 0.8878
